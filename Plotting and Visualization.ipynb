# %% [markdown]
# ## Plotting and Visualization

# %%
# %matplotlib inline
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data = np.arange(10)
plt.plot(data)

# %% [markdown]
# ### Figures and Subplots

# %% [markdown]
# matplotlib 그림은 Figure 객체 속에 있다. plt.figure를 이용해 새로운 그림 객체를 생성할 수 있다.

# %%
fig = plt.figure()

# %%
ax1 = fig.add_subplot(2,2,1)

# %%
ax2 = fig.add_subplot(2,2,2)

# %%
ax3 = fig.add_subplot(2,2,3)

# %%
plt.plot(np.random.randn(50).cumsum(), 'k--')

# %%
ax1.hist(np.random.randn(100), bins=20, color='k', alpha=0.3)
# Out:
# (array([ 1.,  2.,  5.,  2.,  6.,  2.,  3.,  6.,  8., 15., 10.,  3.,  7.,
#          8., 10.,  4.,  4.,  2.,  0.,  2.]),
#  array([-2.1018437 , -1.89458009, -1.68731647, -1.48005286, -1.27278924,
#         -1.06552562, -0.85826201, -0.65099839, -0.44373478, -0.23647116,
#         -0.02920755,  0.17805607,  0.38531968,  0.5925833 ,  0.79984691,
#          1.00711053,  1.21437414,  1.42163776,  1.62890137,  1.83616499,
#          2.0434286 ]),
#  <BarContainer object of 20 artists>)

# %%
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))

# %%
fig, axes = plt.subplots(2, 3)
axes
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
axes[0, 1].plot(np.random.randn(30))

# %% [markdown]
# ### Adjusting the spacing around subplots

# %% [markdown]
# wspace와 hspace는 그림 객체의 너비와 높이에 대한 상대적인 백분율로 표현된다. 다음은 그림간의 간격을 없앤 예이다.

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
for i in range(2):
    for j in range(2):
        axes[i, j].hist(np.random.randn(500), bins=50, color='k', alpha=0.5)

fig.subplots_adjust(wspace=0, hspace=0)

# %% [markdown]
# ### Colors, Markers, and Line Styles

# %%
plt.plot(np.random.randn(30).cumsum(), 'ko--')

# %%
data = np.random.randn(30).cumsum()

# %%
plt.plot(data, 'k--', label='Default')
plt.plot(data, 'k-', drawstyle='steps-post', label='Steps-post')
plt.legend(loc='best')

# %% [markdown]
# ### Ticks, Labels, and Legends

# %% [markdown]
# 2번째 셀에 그림을 그리고 싶으면 다음과 같이 새로운 축을 만들고 플롯을 실행하고 show() 함수를 호출하면 된다. show() 함수는 Figure 객체 설정을 마친 후 마지막에 실행해야 그림이 보인다.

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax1 = fig.add_subplot(2, 1, 1)
ax1.plot(data, 'ko--')a
ax2 = fig.add_subplot(2, 1, 2)
ax2.plot(data, drawstyle='steps-post')
plt.show()

# %% [markdown]
# ### Setting the title, axis labels, ticks, and ticklabels

# %% [markdown]
# 틱(tick)은 x와 y 틱이 있고 눈금의 위치를 표시하는 것이다. 틱라벨(ticklabel)은 틱 위치에 대응되는 문자열을 의미한다. 틱 위치와 틱라벨을 변경하려면 set_xticks와 set_xticklabels 메소드를 사용한다.

# %%
data = np.random.randn(1000).cumsum()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(data)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xticks([0, 250, 500, 750, 1000])
ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'], rotation=30, fontsize='small')
ax.plot(data)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xticks([0, 250, 500, 750, 1000])
ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'], rotation=30, fontsize='small')
ax.set_xlabel('X - axis')
ax.set_title('My Matplotlib Plot')
ax.plot(data)

# %% [markdown]
# Axes 클래스는 set 메소드를 이용해서 성질들을 한꺼번에 설정할 수 있다.

# %%
props = {
    'title': 'My First Plot',
    'xlabel': 'Stages',
    'xticks': [0, 250, 500, 750, 1000]
}

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'], rotation=30, fontsize='small', ha='right')

ax.set(**props)
ax.plot(data)
# Out:
# <ipython-input-31-6df6a1ca23b9>:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'], rotation=30, fontsize='small', ha='right')

# %% [markdown]
# ### 범례달기

# %% [markdown]
# plot 함수의 인자로 label=을 추가하는 것이다. 플롯을 한 후 legend 메소드를 실행하면 된다.

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(np.random.randn(1000).cumsum(), 'k', label='one')
ax.plot(np.random.randn(1000).cumsum(), 'k--', label='two')
ax.plot(np.random.randn(1000).cumsum(), 'k.', label='three')

ax.legend()

# %% [markdown]
# ### 어노테이션 및 도형

# %%
from datetime import datetime

data = pd.read_csv('data/spx.csv', index_col=0, parse_dates=True)
spx = data['SPX']
spx.head()

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

spx.plot(ax=ax, style='k-')

crisis_data = [
    (datetime(2007, 10, 11), 'Peak of bull market'),
    (datetime(2008, 3, 12), 'Bear sterns fails'),
    (datetime(2008, 9, 15), 'Lehman bankruptcy')
]

for date, label in crisis_data:
    ax.annotate(label,
                xy=(date, spx.asof(date) + 75),
                xytext=(date, spx.asof(date) + 225),
                arrowprops=dict(facecolor='black', headwidth=4, headlength=4, width=2),
                horizontalalignment='left',
                verticalalignment='top'
               )

ax.set_xlim(['1/1/2007', '1/1/2011'])
ax.set_ylim([600, 1800])
ax.set_title('Import date in the 2008-2009 financial crisis')

# %%
import matplotlib.patches as pch

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

circ = pch.Circle((0.7, 0.2), radius=0.15, color='b', alpha=0.3)
rect = pch.Rectangle((0.2, 0.75), width=0.4, height=0.15, color='k', alpha=0.3)
pgon = pch.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]], color='g', alpha=0.5)

ax.add_patch(circ)
ax.add_patch(rect)
ax.add_patch(pgon)

# %% [markdown]
# ### 판다스와 seaborn을 이용한 플롯

# %% [markdown]
# #### Line Plots

# %%
s = pd.Series(np.random.randn(10).cumsum(), index = np.arange(0,100,10))
s.plot()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(10, 4).cumsum(0),
                  columns=['A', 'B', 'C', 'D'],
                  index=np.arange(0, 100, 10))
df.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### 막대 그래프

# %%
fig, axes = plt.subplots(2,1)
data = pd.Series(np.random.randn(16), index = list('abcdefghijklmnop'))
data.plot.bar(ax=axes[0], color='k', alpha=0.7)
data.plot.barh(ax=axes[1], color='k', alpha=0.7)
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.rand(6, 4),
                  index=['one', 'two', 'three', 'four', 'five', 'six'],
                  columns=pd.Index(['A', 'B', 'C', 'D'], name='Genus'))
df
# Out:
# Genus         A         B         C         D
# one    0.278684  0.364936  0.035085  0.636019
# two    0.523647  0.266913  0.835346  0.632947
# three  0.877122  0.932333  0.671858  0.062773
# four   0.657575  0.833421  0.290730  0.454137
# five   0.111949  0.196337  0.378791  0.911720
# six    0.963815  0.839069  0.794130  0.339494

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot.barh(stacked=True, alpha=0.5)
# Out:
# <AxesSubplot:>
